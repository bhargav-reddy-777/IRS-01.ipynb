# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-reddy-777/IRS-01.ipynb/blob/main/IRS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import string
from collections import defaultdict

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download required NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Folder containing text documents
DOCS_FOLDER = "docs"

# Initialize data structures
inverted_index = defaultdict(set)
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# Process each text file in the folder
for filename in os.listdir(DOCS_FOLDER):
    if filename.endswith(".txt"):
        doc_id = filename

        with open(os.path.join(DOCS_FOLDER, filename), 'r', encoding='utf-8') as file:
            text = file.read().lower()

            # Remove punctuation
            text = text.translate(
                str.maketrans("", "", string.punctuation)
            )

            # Tokenize words
            tokens = word_tokenize(text)

            # Remove stop words and apply stemming
            processed_tokens = [
                stemmer.stem(word)
                for word in tokens
                if word not in stop_words and word.isalpha()
            ]

            # Build inverted index
            for token in processed_tokens:
                inverted_index[token].add(doc_id)

# Display the inverted index
for term in sorted(inverted_index.keys()):
    print(f"{term}: {sorted(inverted_index[term])}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import os

# Create the DOCS_FOLDER if it doesn't exist
if not os.path.exists(DOCS_FOLDER):
    os.makedirs(DOCS_FOLDER)
    print(f"Created folder: {DOCS_FOLDER}")
else:
    print(f"Folder already exists: {DOCS_FOLDER}")

# You can create some dummy files for testing if needed
# For example:
# with open(os.path.join(DOCS_FOLDER, 'doc1.txt'), 'w') as f:
# f.write('This is the first document.')
# with open(os.path.join(DOCS_FOLDER, 'doc2.txt'), 'w') as f:
# f.write('This is the second document.')
# Out:
# Folder already exists: docs
