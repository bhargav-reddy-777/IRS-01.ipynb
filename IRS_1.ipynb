# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-reddy-777/IRS-01.ipynb/blob/main/IRS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2 = "Artificial intelligence and machine learning are widely used to make smart applications based on data."
documents = [doc1, doc2]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 0.4039

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
documents = [doc1, doc2]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 1.0000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2 = "Welcome to soul society"
documents = [doc1, doc2]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 0.0000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2 = "Artificial intelligence and machine learning are widely used to make smart applications based on data."
doc3 =  "Artificial intelligence serves as the broad vision of enabling machines to mimic human intelligence, while machine learning is the specific core technology—fueled by data and advanced algorithms—that brings this vision to life by allowing systems to learn and adapt autonomously."
documents = [doc1, doc2, doc3]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 0.3533

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc3 =  "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
documents = [doc1, doc2, doc3]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 1.0000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2 = "Welcome to soul society"
doc3 = "open piece is real"
documents = [doc1, doc2, doc3]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 0.0000
